# %%
# !pip install mem0ai "mem0ai[graph]"
# Out:
# /opt/homebrew/Cellar/python@3.13/3.13.4/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=71026) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: mem0ai in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (0.1.117)
# Requirement already satisfied: openai<1.100.0,>=1.90.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (1.99.9)
# Requirement already satisfied: posthog>=3.5.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (6.7.5)
# Requirement already satisfied: protobuf<6.0.0,>=5.29.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (5.29.5)
# Requirement already satisfied: pydantic>=2.7.3 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (2.11.9)
# Requirement already satisfied: pytz>=2024.1 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from mem0ai) (2.0.43)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (0.11.0)
# Requirement already satisfied: sniffio in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from openai<1.100.0,>=1.90.0->mem0ai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai<1.100.0,>=1.90.0->mem0ai) (3.10)
# Requirement already satisfied: certifi in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<1.100.0,>=1.90.0->mem0ai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<1.100.0,>=1.90.0->mem0ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<1.100.0,>=1.90.0->mem0ai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from pydantic>=2.7.3->mem0ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from pydantic>=2.7.3->mem0ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from pydantic>=2.7.3->mem0ai) (0.4.1)
# Collecting kuzu>=0.11.0 (from mem0ai[graph])
#   Downloading kuzu-0.11.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting langchain-aws>=0.2.23 (from mem0ai[graph])
#   Downloading langchain_aws-0.2.33-py3-none-any.whl.metadata (4.5 kB)
# Collecting langchain-neo4j>=0.4.0 (from mem0ai[graph])
#   Downloading langchain_neo4j-0.5.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting neo4j>=5.23.1 (from mem0ai[graph])
#   Downloading neo4j-5.28.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting rank-bm25>=0.2.2 (from mem0ai[graph])
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting boto3>=1.39.7 (from langchain-aws>=0.2.23->mem0ai[graph])
#   Downloading boto3-1.40.34-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.76 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-aws>=0.2.23->mem0ai[graph]) (0.3.76)
# Requirement already satisfied: numpy<3,>=1.26.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-aws>=0.2.23->mem0ai[graph]) (2.3.3)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (0.4.28)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (3.0.0)
# Collecting botocore<1.41.0,>=1.40.34 (from boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph])
#   Downloading botocore-1.40.34-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph])
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph])
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.34->boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.34->boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph]) (2.5.0)
# Requirement already satisfied: six>=1.5 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.34->boto3>=1.39.7->langchain-aws>=0.2.23->mem0ai[graph]) (1.17.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.7 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain-neo4j>=0.4.0->mem0ai[graph]) (0.3.27)
# Collecting neo4j-graphrag<2.0.0,>=1.9.0 (from langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading neo4j_graphrag-1.10.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.4.0->mem0ai[graph]) (0.3.11)
# Requirement already satisfied: requests<3,>=2 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.4.0->mem0ai[graph]) (2.32.5)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading pypdf-6.0.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting scipy<2.0.0,>=1.15.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j>=0.4.0->mem0ai[graph])
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.4.0->mem0ai[graph]) (3.4.3)
# Requirement already satisfied: orjson>=3.9.14 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws>=0.2.23->mem0ai[graph]) (0.25.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from posthog>=3.5.0->mem0ai) (2.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from qdrant-client>=1.9.1->mem0ai) (1.75.0)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from qdrant-client>=1.9.1->mem0ai) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/hammermt/Codes/ai-agents-udemy-course/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.1.0)
# Downloading kuzu-0.11.2-cp313-cp313-macosx_11_0_arm64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 8.3 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_aws-0.2.33-py3-none-any.whl (143 kB)
# Downloading boto3-1.40.34-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.34-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 9.2 MB/s  0:00:01 eta 0:00:01
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Downloading langchain_neo4j-0.5.0-py3-none-any.whl (31 kB)
# Downloading neo4j-5.28.2-py3-none-any.whl (313 kB)
# Downloading neo4j_graphrag-1.10.0-py3-none-any.whl (201 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading pypdf-6.0.0-py3-none-any.whl (310 kB)
# Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 9.2 MB/s  0:00:02m0:00:0100:01
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: kuzu, types-pyyaml, scipy, rank-bm25, pypdf, neo4j, json-repair, jmespath, fsspec, botocore, s3transfer, neo4j-graphrag, boto3, langchain-aws, langchain-neo4j
#   Attempting uninstall: json-repair0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/15 [pypdf]
#     Found existing installation: json_repair 0.50.1━━━━━━━━━━━  4/15 [pypdf]
#     Uninstalling json_repair-0.50.1:━━━━━━━━━━━━━━━━━━━━━━━━━━  4/15 [pypdf]
#       Successfully uninstalled json_repair-0.50.1━━━━━━━━━━━━━  4/15 [pypdf]
#   Attempting uninstall: fsspec╸━━━━━━━━━━━━━━━━━━━━━  7/15 [jmespath]
#     Found existing installation: fsspec 2025.9.0━━━━━━━━━━━━━━  7/15 [jmespath]
#     Uninstalling fsspec-2025.9.0:━━━━━━━━━━━━━━━━━━━━━  7/15 [jmespath]
#       Successfully uninstalled fsspec-2025.9.0━━━━━━━━━━━━━━━━  7/15 [jmespath]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [langchain-neo4j] [langchain-aws]
# Successfully installed boto3-1.40.34 botocore-1.40.34 fsspec-2024.12.0 jmespath-1.0.1 json-repair-0.44.1 kuzu-0.11.2 langchain-aws-0.2.33 langchain-neo4j-0.5.0 neo4j-5.28.2 neo4j-graphrag-1.10.0 pypdf-6.0.0 rank-bm25-0.2.2 s3transfer-0.14.0 scipy-1.16.2 types-pyyaml-6.0.12.20250915

# %%
import dspy
from mem0 import Memory
import os
from typing import List, Dict, Any, Optional
from datetime import datetime
q_host = os.getenv("QDRANT_HOST", "localhost")
q_port_val = int(os.getenv("QDRANT_PORT", "6333"))
neo4j_uri = os.getenv("NEO4J_URI", "bolt://localhost:7687")
neo4j_user = os.getenv("NEO4J_USERNAME", "neo4j")
neo4j_pass = os.getenv("NEO4J_PASSWORD", "mem0-graph")

# Configure environment
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# Initialize Mem0 memory system
config = {
    "llm": {
        "provider": "openai",
        "config": {
            "model": "gpt-4o-mini",
            "temperature": 0.1
        }
    },
    "embedder": {
        "provider": "openai",
        "config": {
            "model": "text-embedding-3-small"
        }
    },
    "vector_store": {
        "provider": "qdrant",
        "config": {
            "host": q_host,
            "port": q_port_val,
        },
    },
    "graph_store": {
        "provider": "neo4j",
        "config": {
            "url": neo4j_uri,
            "username": neo4j_user,
            "password": neo4j_pass,
        }
    }
}

# %%
import datetime

class MemoryTools:
    """Tools for interacting with the Mem0 memory system."""

    def __init__(self, memory: Memory):
        self.memory = memory

    def store_memory(self, content: str, user_id: str = "default_user") -> str:
        """Store information in memory."""
        try:
            self.memory.add(content, user_id=user_id)
            return f"Stored memory: {content}"
        except Exception as e:
            return f"Error storing memory: {str(e)}"

    def search_memories(self, query: str, user_id: str = "default_user", limit: int = 5) -> str:
        """Search for relevant memories."""
        try:
            results = self.memory.search(query, user_id=user_id, limit=limit)
            if not results:
                return "No relevant memories found."

            memory_text = "Relevant memories found:\n"
            for i, result in enumerate(results["results"]):
                memory_text += f"{i}. {result['memory']}\n"
            return memory_text
        except Exception as e:
            return f"Error searching memories: {str(e)}"

    def get_all_memories(self, user_id: str = "default_user") -> str:
        """Get all memories for a user."""
        try:
            results = self.memory.get_all(user_id=user_id)
            if not results:
                return "No memories found for this user."

            memory_text = "All memories for user:\n"
            for i, result in enumerate(results["results"]):
                memory_text += f"{i}. {result['memory']}\n"
            return memory_text
        except Exception as e:
            return f"Error retrieving memories: {str(e)}"

    def update_memory(self, memory_id: str, new_content: str) -> str:
        """Update an existing memory."""
        try:
            self.memory.update(memory_id, new_content)
            return f"Updated memory with new content: {new_content}"
        except Exception as e:
            return f"Error updating memory: {str(e)}"

    def delete_memory(self, memory_id: str) -> str:
        """Delete a specific memory."""
        try:
            self.memory.delete(memory_id)
            return "Memory deleted successfully."
        except Exception as e:
            return f"Error deleting memory: {str(e)}"

def get_current_time() -> str:
    """Get the current date and time."""
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
class MemoryQA(dspy.Signature):
    """
    You're a helpful assistant and have access to memory method.
    Whenever you answer a user's input, remember to store the information in memory
    so that you can use it later.
    """
    user_input: str = dspy.InputField()
    response: str = dspy.OutputField()

class MemoryReActAgent(dspy.Module):
    """A ReAct agent enhanced with Mem0 memory capabilities."""

    def __init__(self, memory: Memory):
        super().__init__()
        self.memory_tools = MemoryTools(memory)

        # Create tools list for ReAct
        self.tools = [
            self.memory_tools.store_memory,
            self.memory_tools.search_memories,
            self.memory_tools.get_all_memories,
            get_current_time,
            self.set_reminder,
            self.get_preferences,
            self.update_preferences,
        ]

        # Initialize ReAct with our tools
        self.react = dspy.ReAct(
            signature=MemoryQA,
            tools=self.tools,
            max_iters=6
        )

    def forward(self, user_input: str):
        """Process user input with memory-aware reasoning."""

        return self.react(user_input=user_input)

    def set_reminder(self, reminder_text: str, date_time: str = None, user_id: str = "default_user") -> str:
        """Set a reminder for the user."""
        reminder = f"Reminder set for {date_time}: {reminder_text}"
        return self.memory_tools.store_memory(
            f"REMINDER: {reminder}", 
            user_id=user_id
        )

    def get_preferences(self, category: str = "general", user_id: str = "default_user") -> str:
        """Get user preferences for a specific category."""
        query = f"user preferences {category}"
        return self.memory_tools.search_memories(
            query=query,
            user_id=user_id
        )

    def update_preferences(self, category: str, preference: str, user_id: str = "default_user") -> str:
        """Update user preferences."""
        preference_text = f"User preference for {category}: {preference}"
        return self.memory_tools.store_memory(
            preference_text,
            user_id=user_id
        )

# %%
import time
def run_memory_agent_demo():
    """Demonstration of memory-enhanced ReAct agent."""

    # Configure DSPy
    lm = dspy.LM(model='openai/gpt-4o-mini')
    dspy.configure(lm=lm)

    # Initialize memory system
    memory = Memory.from_config(config)

    # Create our agent
    agent = MemoryReActAgent(memory)

    # Sample conversation demonstrating memory capabilities
    print("🧠 Memory-Enhanced ReAct Agent Demo")
    print("=" * 50)

    conversations = [
        "Hi, I'm Alice and I love Italian food, especially pasta carbonara.",
        "I'm Alice. I prefer to exercise in the morning around 7 AM.",
        "I'm Alice. What do you remember about my food preferences?",
        "I'm Alice. Set a reminder for me to go grocery shopping tomorrow.",
        "I'm Alice. What are my exercise preferences?",
        "I'm Alice. I also enjoy hiking on weekends.",
        "I'm Alice. What do you know about me so far?"
    ]

    for i, user_input in enumerate(conversations, 1):
        print(f"\n📝 User: {user_input}")

        try:
            response = agent(user_input=user_input)
            print(f"🤖 Agent: {response.response}")
            time.sleep(1)

        except Exception as e:
            print(f"❌ Error: {e}")

run_memory_agent_demo()
# Out:
# 🧠 Memory-Enhanced ReAct Agent Demo
# ==================================================
#
# 📝 User: Hi, I'm Alice and I love Italian food, especially pasta carbonara.
# 🤖 Agent: Hi Alice! It's great to meet you. Pasta carbonara is a delicious choice! If you have any questions about Italian food or need recommendations, feel free to ask!
#
# 📝 User: I'm Alice. I prefer to exercise in the morning around 7 AM.
# 🤖 Agent: Nice to meet you, Alice! I've noted that you prefer to exercise in the morning around 7 AM. If you have any other preferences or questions, feel free to share!
#
# 📝 User: I'm Alice. What do you remember about my food preferences?
# 🤖 Agent: I remember that you love Italian food, especially pasta carbonara. Is there anything else you'd like to share about your food preferences?
#
# 📝 User: I'm Alice. Set a reminder for me to go grocery shopping tomorrow.
# 🤖 Agent: I have set a reminder for you, Alice, to go grocery shopping tomorrow, October 7th.
#
# 📝 User: I'm Alice. What are my exercise preferences?
# 🤖 Agent: Your exercise preference is to work out in the morning around 7 AM.
#
# 📝 User: I'm Alice. I also enjoy hiking on weekends.
# 🤖 Agent: Nice to meet you, Alice! It's great to hear that you enjoy hiking on weekends. If you have any favorite trails or hiking experiences you'd like to share, feel free to let me know!
#
# 📝 User: I'm Alice. What do you know about me so far?
# 🤖 Agent: So far, I know that you love Italian food, especially pasta carbonara. You enjoy hiking on weekends and prefer to exercise in the morning around 7 AM. If there's anything else you'd like to share or ask, feel free!
