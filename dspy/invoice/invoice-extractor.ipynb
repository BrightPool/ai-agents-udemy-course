# %%
# Install dependencies (run once per environment)
# %pip install -q dspy pandas python-dotenv

# dataset comes from here: https://www.kaggle.com/datasets/nikitpatel/invoice-ner-dataset?resource=download
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Basic imports and environment setup
import os
import json
import dspy
import pandas as pd
from dotenv import load_dotenv

# Load API keys from .env (OPENAI_API_KEY is expected)
load_dotenv()

# Configure DSPy default LM similar to other notebooks
lm = dspy.LM("openai/gpt-5-mini", api_key=os.getenv("OPENAI_API_KEY"), temperature=1, max_tokens=16000)
dspy.configure(lm=lm)

print("DSPy configured for invoice extraction.")
# Out:
# DSPy configured for invoice extraction.

# %%
# Load dataset and preview a few rows
# Prefer absolute path next to this notebook; fallback to project root
nb_dir = os.path.dirname(os.path.abspath("__file__")) if "__file__" in globals() else os.path.abspath("./dspy")
candidates = [
    os.path.abspath("invoice_ner_clean.csv"),
]
for p in candidates:
    if os.path.exists(p):
        csv_path = p
        break
else:
    raise FileNotFoundError("invoice_ner_clean.csv not found in expected locations")

raw_df = pd.read_csv(csv_path)
print("Rows:", len(raw_df))
print(raw_df.head(2))

# Parse Final_Output JSON strings into dicts
raw_df["Final_Output"] = raw_df["Final_Output"].apply(lambda s: json.loads(s))

# Build small train/test splits for quick iteration
# Keep it tiny for a simple example; adjust as needed
train_df = raw_df.iloc[:30].copy()
valid_df = raw_df.iloc[30:40].copy()

def to_examples(df):
    examples = []
    for _, row in df.iterrows():
        examples.append(dspy.Example(text=row["Input"], target=row["Final_Output"]).with_inputs("text"))
    return examples

train_examples = to_examples(train_df)
valid_examples = to_examples(valid_df)

print(f"Train examples: {len(train_examples)}, Valid examples: {len(valid_examples)}")
# Out:
# Rows: 39
#                                                Input  \
# 0  Beige Elegant Professional Business Invoice\n\...
# 1  Black and White Clean Modern Invoice\n\nConsul...
#
#                                         Final_Output
# 0  {"invoice_number":"1234","invoice_date":"2030-...
# 1  {"invoice_number":"INV-01234","invoice_date":"...
# Train examples: 30, Valid examples: 9

# %%
# Define a signature for extracting a JSON dict of invoice fields
class InvoiceExtraction(dspy.Signature):
    """
    Extract key-value invoice fields as a JSON dict from free-form invoice text.
    """
    text: str = dspy.InputField(description="Raw invoice text")
    rationale: str = dspy.OutputField(description="Brief reasoning, list detected fields")
    extracted: dict = dspy.OutputField(description="JSON dict with dataset keys and string values")

# Base module (simple Predict)
extractor = dspy.Predict(InvoiceExtraction)

print("Signature and extractor ready.")
# Out:
# Signature and extractor ready.

# %%
# Define a per-field partial-credit metric: +0.5 for key presence, +0.5 for exact value
from dspy.evaluate import Evaluate


def field_accuracy_metric(example: dspy.Example, pred: dspy.Prediction, trace=None, pred_name=None, pred_trace=None) -> float:
    """
    Per-field partial-credit metric (no normalization):
    - +0.5 if a gold key is present exactly in the prediction
    - +0.5 if the predicted value equals the gold value exactly
    Extra keys are ignored. Returns float or dspy.Prediction with feedback for GEPA.
    """
    gold = example.target or {}
    got = getattr(pred, "extracted", {}) or {}

    if not gold:
        return 0.0 if pred_name is None else dspy.Prediction(score=0.0, feedback="No gold fields present.")

    total = len(gold)
    present = 0
    correct = 0
    missing_keys = []
    mismatched_keys = []

    for k, v in gold.items():
        if k in got:
            present += 1
            if got[k] == v:
                correct += 1
            else:
                mismatched_keys.append(k)
        else:
            missing_keys.append(k)

    score = (0.5 * present + 0.5 * correct) / total

    if pred_name is None:
        return score

    # Build concise feedback for GEPA
    lines = [
        f"Keys present: {present}/{total}. Values correct: {correct}/{total}.",
    ]
    if missing_keys:
        lines.append(f"Missing keys: {', '.join(missing_keys[:8])}.")
    if mismatched_keys:
        lines.append(f"Mismatched keys: {', '.join(mismatched_keys[:8])}.")

    feedback = "\n".join(lines)
    return dspy.Prediction(score=score, feedback=feedback)


# Provide the devset at construction per latest API
evaluate = Evaluate(devset=valid_examples, metric=field_accuracy_metric, ordered=True)

# Standard usage: pass the module directly
initial_score = evaluate(extractor)
print("Initial field accuracy on valid:", initial_score)
# Out:
# 2025/09/17 09:43:16 INFO dspy.evaluate.evaluate: Average Metric: 2.375 / 9 (26.4%)
# Initial field accuracy on valid: EvaluationResult(score=26.39, results=<list of 9 results>)

# %%
# Compare base vs optimized predictions on a sample
sample = valid_examples[0]
print("Sample comparison:")
print("\nINPUT TEXT:")
print("-" * 80)
print(sample.text[:300], "...")
print("-" * 80)

print("\nBASE MODEL PREDICTION:")
base_pred = extractor(text=sample.text)
print(f"Rationale: {base_pred.rationale}")
print("\nExtracted fields:")
for k,v in (base_pred.extracted or {}).items():
    print(f"{k:20s}: {v}")

print("\nGROUND TRUTH:")
print("\nExtracted fields:")
for k,v in sample.target.items():
    print(f"{k:20s}: {v}")
# Out:
# Sample comparison:
#
# INPUT TEXT:
# --------------------------------------------------------------------------------
# Yellow and Black Professional Company Invoice
#
# No Items Qty Price Total
# 1 Cement 50 $20.00 $1000.00
# 2 Pvc Pipe 10 $10.00 $100.00
# 3 Brick 10 $10.00 $100.00
# 4 Wood Board 10 $10.00 $100.00
# Taylor Alonso
# Ginyard International Bank
# Bank Code (123-456-7890)
# Total $1200.00
# INVOICE
# Ingoude
# Company
# Jonathan  ...
# --------------------------------------------------------------------------------
#
# BASE MODEL PREDICTION:
# Rationale: Parsed the invoice text and extracted identifiable fields. Detected:
# - Vendor: "Yellow and Black Professional Company"
# - Invoice number: "#123456789"
# - Invoice date: "3rd January 2024" (ISO: 2024-01-03)
# - Line items (4): Cement, Pvc Pipe, Brick, Wood Board with qty, unit price, line totals
# - Calculated subtotal from line items: $1300.00
# - Total shown on invoice: $1200.00 (mismatch vs calculated subtotal)
# - Bank: "Ginyard International Bank" and "Bank Code (123-456-7890)"
# - Contacts / parties: "Ingoude Company" (Invoice to / billed party), "Jonathan Patterson" (+123-456-7890), "Taylor Alonso"
# - Payment terms text present (lorem ipsum)
#
# Extracted fields:
# vendor_name         : Yellow and Black Professional Company
# invoice_number      : #123456789
# invoice_date        : 2024-01-03 (3rd January 2024)
# billed_to           : Ingoude Company
# issuer_contact      : Jonathan Patterson
# issuer_phone        : +123-456-7890
# authorized_by       : Taylor Alonso
# bank_name           : Ginyard International Bank
# bank_code           : 123-456-7890
# payment_terms       : Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# currency            : USD
# subtotal            : $1300.00 (calculated from line items)
# total_due           : $1200.00 (as shown on invoice)
# discrepancy_note    : Sum of line item totals ($1300.00) does not match invoice total ($1200.00).
# items               : [{"line":"1","description":"Cement","quantity":"50","unit_price":"$20.00","total":"$1000.00"}, {"line":"2","description":"Pvc Pipe","quantity":"10","unit_price":"$10.00","total":"$100.00"}, {"line":"3","description":"Brick","quantity":"10","unit_price":"$10.00","total":"$100.00"}, {"line":"4","description":"Wood Board","quantity":"10","unit_price":"$10.00","total":"$100.00"}]
#
# GROUND TRUTH:
#
# Extracted fields:
# invoice_number      : 123456789
# invoice_date        : 2024-01-03
# billed_to           : Jonathan Patterson
# company             : Ingoude
# total_amount        : 1200
# bank_name           : Ginyard International Bank
# account_name        :
# account_number      :

# %%
# Optimize with GEPA (similar to comedian-agent)
from dspy import GEPA

optimizer = GEPA(
    metric=field_accuracy_metric,
    max_full_evals=3,
    num_threads=8,
    track_stats=True,
    use_merge=False,
    reflection_lm=dspy.LM(model='gpt-5', temperature=1.0, max_tokens=32000),
)

optimized_program = optimizer.compile(
    extractor,
    trainset=train_examples,
    valset=valid_examples,
)

# Standard usage: evaluate the optimized program directly
opt_score = evaluate(optimized_program)
print("Optimized field accuracy on valid:", opt_score)
# Out:
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Running GEPA for approx 117 metric calls of the program. This amounts to 3.00 full evals on the train+val set.
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Using 9 examples for tracking Pareto scores. You can consider using a smaller sample of the valset to allow GEPA to explore more diverse solutions within the same budget.
# GEPA Optimization:   0%|          | 0/117 [00:00<?, ?rollouts/s]2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 2.375 / 9 (26.4%)
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 0: Base program full valset score: 0.2638888888888889
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Selected program 0 score: 0.2638888888888889
# Average Metric: 0.94 / 3 (31.2%): 100%|██████████| 3/3 [00:00<00:00, 3479.79it/s]
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 0.9375 / 3 (31.2%)
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Proposed new text for self: Task:
# From free-form invoice text, extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Output format:
# - Return a single JSON object (not wrapped, no comments, no rationale).
# - Include exactly these 8 keys (all keys must be present, even if the value is unknown):
#   1) company
#   2) billed_to
#   3) invoice_number
#   4) date
#   5) total_amount
#   6) bank_name
#   7) account_name
#   8) account_number
# - Use string values for all fields.
# - If a field is not present in the text, set it to "" (empty string).
# - Do not include any extra keys (no addresses, emails, line items, notes, etc. unless they are part of the 8 required keys).
#
# Field definitions and extraction rules:
# - company:
#   - The issuing/seller entity (the party sending the invoice).
#   - Look for labels/contexts like: “From”, “FROM:”, “Seller”, “Vendor”, “Company”, prominent brand/header name near “INVOICE”.
#   - Prefer the explicit “From/From:” block when available. If absent, use the prominent brand/company name at the top.
#   - Value should be just the name (do not include address, phone, or email).
#
# - billed_to:
#   - The customer/recipient being invoiced (the party being billed).
#   - Look for labels like: “Bill To”, “Billed To”, “Invoice to”, “Customer”, “Client”.
#   - Prefer the company name if both a company and a contact person are listed; otherwise use the person’s name if that’s all that’s available.
#   - Use only the name (do not include address, phone, or email).
#
# - invoice_number:
#   - The invoice identifier.
#   - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”.
#   - Extract the value exactly as shown (preserve hyphens/leading zeros, e.g., “INV-00001”, “2000-15”, “001”).
#
# - date:
#   - The invoice date (not service date, not due date).
#   - Prefer “Invoice Date” if present. If only a generic “Date” appears, use that. Do not use “Service Date” or “Due Date” for this field.
#   - Keep the original formatting from the source (e.g., “01/01/2023”, “15/08/2028”).
#
# - total_amount:
#   - The grand total amount due for the invoice.
#   - Prefer labels like “TOTAL”, “TOTAL AMOUNT DUE”, “Amount Due”, “Total amount”.
#   - Do not supply sub-total or tax amounts here; choose the final total.
#   - Preserve currency symbols and formatting (e.g., “$625.00”, “$ 346.50”, “€1.234,56”).
#
# - bank_name:
#   - The bank’s name where payment should be made, if specified.
#   - Look for “Bank Name”, “Bank”.
#   - Do NOT use “Bank Code” as bank_name unless the text explicitly names the bank.
#
# - account_name:
#   - The name on the bank account.
#   - Look for “Account Name”.
#   - Do not map “Payment Method” or administrator names to account_name unless the text explicitly says “Account Name”.
#
# - account_number:
#   - The bank account number.
#   - Look for “Account Number”, “Account No”, “Acct No”, “A/C No”.
#   - Preserve formatting (e.g., keep dashes if present: “123-456-7890”).
#
# General guidance:
# - Choose the clearest, explicitly labeled values. If multiple candidates exist, pick the one closest to the relevant label (e.g., for date, the one labeled “Invoice Date”; for total, the “TOTAL”/“Amount Due” figure).
# - Do not infer or fabricate values.
# - Do not output any additional fields (addresses, phones, emails, line items, taxes, notes, websites, currency codes, or diagnostic notes).
# - Always include all 8 keys with string values; use "" when not available.
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 1.9375 / 3 (64.6%)
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 5.875 / 9 (65.3%)
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New program is on the linear pareto front
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Full valset score for new program: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Full train_val score for new program: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Individual valset scores for new program: [0.625, 0.625, 0.75, 0.5, 0.75, 0.625, 0.6875, 0.625, 0.6875]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New valset pareto front scores: [0.625, 0.625, 0.75, 0.5, 0.75, 0.625, 0.6875, 0.625, 0.6875]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Full valset pareto front score: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Updated valset pareto front programs: [{1}, {1}, {1}, {1}, {1}, {1}, {1}, {1}, {1}]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best valset aggregate score so far: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best program as per aggregate score on train_val: 1
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best program as per aggregate score on valset: 1
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best score on valset: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best score on train_val: 0.6527777777777778
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Linear pareto front program index: 1
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New program candidate index: 1
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Selected program 1 score: 0.6527777777777778
# Average Metric: 1.94 / 3 (64.6%): 100%|██████████| 3/3 [00:00<00:00, 4845.17it/s]
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 1.9375 / 3 (64.6%)
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Proposed new text for self: Task
# From free-form invoice text (plain text), extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Output format
# - Return a single JSON object (not wrapped, no comments, no rationale).
# - Include exactly these 8 keys (all must be present, even if unknown), with string values:
#   1) "company"
#   2) "billed_to"
#   3) "invoice_number"
#   4) "date"
#   5) "total_amount"
#   6) "bank_name"
#   7) "account_name"
#   8) "account_number"
# - If a field is not present in the text, set it to "" (empty string).
# - Do not include any extra keys or metadata. Do NOT rename any keys (e.g., do not use "invoice_date"; the correct key is "date").
#
# General extraction strategy
# - Parse the text for clearly labeled fields first. Prefer values explicitly tied to labels over inferred or stylistic text.
# - When multiple candidates exist, pick the one closest to the relevant label. Avoid using generic or template/branding lines that are not explicitly tied to a field.
# - Preserve the exact formatting of extracted values (e.g., retain currency symbols, thousands separators, leading zeros, and prefix characters like “#” in invoice numbers; retain spaces/dashes in account numbers).
# - Never fabricate values. If not explicitly present, return "".
#
# Field-specific rules
#
# 1) company (the issuing/seller entity)
# - What to look for (in this order of preference):
#   a) Explicit seller blocks/labels: “From”, “FROM:”, “Seller”, “Vendor”, “Supplier”, “Issued by”, “Company”, “PAY TO” / “Pay To”.
#   b) Role labels identifying the issuer, e.g., “Freelancer: <name>”, “Consultant: <name>”.
#   c) The prominent brand/company name near the invoice header only if it clearly denotes a real entity (not a template/theme title).
# - Do NOT use design/template names or generic headings as the company (e.g., “White Modern Sales Invoice”, “Beige Elegant Professional Business Invoice”, “Freelance Invoice Template” are NOT company names).
# - If both a company and a person are listed in the issuer block, prefer the company name. If only a person’s name appears, use that.
# - Extract only the name; do not include address, phone, email, or URLs.
#
# 2) billed_to (the customer/recipient being invoiced)
# - Look for: “Bill To”, “Billed To”, “Invoice To”, “Customer”, “Client”, “To:”.
# - Prefer the company name if both a company and a contact person are listed; if only a person name is present, use that person’s name.
# - Extract only the name; do not include address, phone, email, or URLs.
# - Important disambiguation: “PAY TO” (or “Pay To”) indicates the issuer/seller, NOT the customer. Do not use “PAY TO” for billed_to.
#
# 3) invoice_number
# - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO.”.
# - Also accept a standalone “#12345” near the invoice header when clearly serving as the invoice number.
# - Extract the value exactly as shown, preserving hyphens, leading zeros, and prefix characters (e.g., “#01234”, “INV-00008”, “2000-15”, “001”).
#
# 4) date (the invoice date)
# - Prefer labels like “Invoice Date”, “Date of Issue”, “Issue Date”, “Date”.
# - Do NOT use “Service Date”, “Due Date”, or “Payment Date” for this field.
# - If only an unlabeled date appears near the invoice header/number and no other date types are present, use it as the invoice date.
# - Preserve the original formatting (e.g., “08/01/2023”, “15/01/2028”, “5 December 2030”).
# - Key name must be exactly "date" (do not use "invoice_date").
#
# 5) total_amount (grand total due)
# - Prefer labels such as: “TOTAL”, “TOTAL AMOUNT DUE”, “TOTAL AMOUNT”, “Amount Due”, “Balance Due”, “Grand Total”.
# - Choose the final total from the summary/totals section (often at or near the end), not line-item totals.
# - Do NOT use “Sub-Total”, “Subtotal”, “Tax”, “Discount”, or intermediate sums.
# - If multiple total-like amounts appear, pick the one nearest the clearest total label in the summary block.
# - Preserve currency symbols and formatting (e.g., “$900.00”, “$ 2,000.00”, “€1.234,56”).
#
# 6) bank_name
# - Look for “Bank Name:”, “Bank:”, or a bank line within a “Bank Details/Bank Information” block.
# - If inside a bank details section a standalone line is clearly the bank’s name (e.g., “Borcelle Bank”), use it.
# - Do NOT use “Bank Code” as bank_name unless the actual bank name is explicitly provided.
#
# 7) account_name
# - Look for “Account Name”, “Account Holder”, “Beneficiary Name” within bank/payment details.
# - Use the explicit value as labeled; do not infer from unrelated context.
# - Do not map administrator names or payment methods to account_name unless explicitly labeled as such.
#
# 8) account_number
# - Look for “Account Number”, “Account No”, “Acct No”, “A/C No”, “AC No.”, “A/C #”.
# - Preserve formatting (retain spaces/dashes), e.g., “123-456-7890”, “0123 4567 8901”.
# - If only IBAN is provided and no account number is present, you may use the IBAN as account_number (preserve its formatting).
# - Do NOT use routing numbers, bank codes, or SWIFT/BIC as account_number.
#
# Disambiguation and edge cases
# - Template/theme headings: Ignore descriptive titles like color/style (“White Modern Sales Invoice”, “Beige Elegant Professional Business Invoice”, “Freelance Invoice Template”). These are not company names.
# - “Freelancer: <name>” typically denotes the issuer; “Customer/Client/Bill To” denotes the recipient.
# - “PAY TO” denotes the issuer (seller), not the recipient.
# - Multi-line blocks: When a block contains name + address, extract only the name line for company or billed_to.
# - If a clearly labeled bank detail contradicts other roles (e.g., account_name equals the customer name), still extract the labeled value for the bank fields as-is; do not reinterpret roles.
# - If a field cannot be confidently located, set it to "".
#
# Final output
# - Return exactly one JSON object with the 8 keys and string values, nothing else.
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 2.0625 / 3 (68.8%)
# 2025/09/17 09:57:37 INFO dspy.evaluate.evaluate: Average Metric: 5.9375 / 9 (66.0%)
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: New program is on the linear pareto front
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Full valset score for new program: 0.6597222222222222
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Full train_val score for new program: 0.6597222222222222
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Individual valset scores for new program: [0.625, 0.625, 0.75, 0.5625, 0.8125, 0.5625, 0.6875, 0.625, 0.6875]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: New valset pareto front scores: [0.625, 0.625, 0.75, 0.5625, 0.8125, 0.625, 0.6875, 0.625, 0.6875]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Full valset pareto front score: 0.6666666666666666
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Updated valset pareto front programs: [{1, 2}, {1, 2}, {1, 2}, {2}, {2}, {1}, {1, 2}, {1, 2}, {1, 2}]
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Best valset aggregate score so far: 0.6597222222222222
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Best program as per aggregate score on train_val: 2
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Best program as per aggregate score on valset: 2
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Best score on valset: 0.6597222222222222
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Best score on train_val: 0.6597222222222222
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: Linear pareto front program index: 2
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 2: New program candidate index: 2
# 2025/09/17 09:57:37 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Selected program 1 score: 0.6527777777777778
# Average Metric: 1.94 / 3 (64.6%): 100%|██████████| 3/3 [00:26<00:00,  8.71s/it]
# 2025/09/17 09:58:03 INFO dspy.evaluate.evaluate: Average Metric: 1.9375 / 3 (64.6%)
# 2025/09/17 09:59:30 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Proposed new text for self: Task:
# From free-form invoice text, extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Output format (strict):
# - Return a single JSON object only (no wrapper, no comments, no rationale).
# - Include exactly these 8 keys (all 8 must be present, even if unknown):
#   1) company
#   2) billed_to
#   3) invoice_number
#   4) invoice_date
#   5) total_amount
#   6) bank_name
#   7) account_name
#   8) account_number
# - Use string values for all fields.
# - If a field is not present in the text, set it to "" (empty string).
# - Do not include any extra keys (no addresses, emails, line items, notes, etc.).
#
# Field definitions and extraction rules:
#
# - company (issuer/seller sending the invoice):
#   - Look for clear issuer blocks such as “From”, “FROM:”, “Seller”, “Vendor”, “Company”, “Service Provider”, “PAY TO:” (issuer’s payee details).
#   - Also consider the prominent brand/header near “INVOICE”.
#   - If both a person and a company name appear together for the issuer, prefer the company name (e.g., choose “Wardi LLC” over “Olivia Wilson”).
#   - If there is a distinct “PAY TO” block, treat the entity named there as the issuer; prefer the company name in that block if present.
#   - Value should be just the name (no address, phone, email, or extra lines).
#
# - billed_to (customer/recipient being invoiced):
#   - Look for labels like: “Bill To”, “Billed To”, “Invoice To”, “Customer”, “Client”, “Ship To” (if clearly used as billing/customer).
#   - If both a company and a contact person are listed under the billed-to label, prefer the company name; otherwise use the person’s name if that’s all that’s available.
#   - If no explicit billed-to label exists but two distinct parties are clearly indicated (e.g., a law firm and an individual name with contact lines), infer the billed_to as the non-issuer party name appearing near address/contact details (choose only the name line).
#   - Use only the name (no address, phone, or email).
#
# - invoice_number:
#   - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO:”, “#<number>” near the invoice header.
#   - Extract the identifier value exactly, preserving hyphens and leading zeros (e.g., “INV-00001”, “2000-15”, “001”).
#   - Remove any leading “#” symbol from the value (e.g., “#91028829” → “91028829”).
#   - Do not include label text or trailing punctuation.
#
# - invoice_date:
#   - The invoice date (not service date, not due date).
#   - Prefer labels like “Invoice Date”, “DATE:”, “Date of Issue”, “DATE OF ISSUE”.
#   - If only a generic “Date” appears near the invoice header info, use that.
#   - Keep the original formatting (e.g., “01/01/2023”, “15/08/2028”, “11.02.2030”).
#
# - total_amount (grand total due):
#   - Prefer explicit grand-total labels such as: “TOTAL”, “TOTAL AMOUNT”, “TOTAL AMOUNT DUE”, “Amount Due”, “Balance Due”, “Total amount”.
#   - Do not use subtotal, tax, or partial totals.
#   - If multiple totals are present, choose the final grand total, typically the one after taxes/discounts, often near the bottom or in an emphasized total section.
#   - Preserve currency symbols and formatting (e.g., “$625.00”, “$ 346.50”, “€1.234,56”).
#   - If both “Total Amount” and “Total” appear, use the final grand total value (often the bottom-most or the one in the “Amount Due”/“TOTAL” box).
#
# - bank_name:
#   - The bank’s name where payment should be made.
#   - Look for labels: “Bank Name”, “Bank:”.
#   - Prefer a textual bank name (alphabetic words). Do NOT take numeric strings or codes as the bank name.
#   - Do NOT use “Bank Code” as bank_name unless the bank’s name is explicitly provided.
#   - If the “Bank:” label is present but the value is on an adjacent line (above or below), use the nearest textual bank name.
#
# - account_name:
#   - The name on the bank account.
#   - Look for labels: “Account Name”, “Acct. Name”, “Account Holder”, “Beneficiary”.
#   - Do not map “Payment Method” or administrative names unless explicitly labeled as the account name/holder/beneficiary.
#
# - account_number:
#   - The bank account number.
#   - Look for labels: “Account Number”, “Account No”, “Acct No”, “Acct. No.”, “Account #”, “A/C No”, “A/C #”, “IBAN” (if this is the only account number provided).
#   - Preserve formatting (e.g., keep spaces/dashes: “123-456-7890”, “0123 4567 8901”).
#   - If label and value appear on separate lines, associate the nearest plausible number with the label.
#
# General guidance:
# - Use the clearest, explicitly labeled values. When multiple candidates exist, pick the one closest to its label.
# - Labels and values may be split across adjacent lines; associate them by proximity and plausibility (e.g., bank names are words; account numbers are numeric/alphanumeric).
# - Prefer issuer/company names over individual names when both appear for the same role.
# - Do not infer or fabricate values beyond the minimal inference allowed to identify the non-issuer party as billed_to when no labeled billed-to exists but two parties are clearly present.
# - Ignore addresses, emails, phone numbers, websites, line items, and notes unless part of the 8 required fields.
# - Always include all 8 keys with string values; use "" when not available.
# 2025/09/17 10:00:33 INFO dspy.evaluate.evaluate: Average Metric: 2.1875 / 3 (72.9%)
# 2025/09/17 10:01:10 INFO dspy.evaluate.evaluate: Average Metric: 6.3125 / 9 (70.1%)
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: New program is on the linear pareto front
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Full valset score for new program: 0.7013888888888888
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Full train_val score for new program: 0.7013888888888888
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Individual valset scores for new program: [0.6875, 0.6875, 0.8125, 0.625, 0.8125, 0.6875, 0.625, 0.625, 0.75]
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: New valset pareto front scores: [0.6875, 0.6875, 0.8125, 0.625, 0.8125, 0.6875, 0.6875, 0.625, 0.75]
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Full valset pareto front score: 0.7083333333333334
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Updated valset pareto front programs: [{3}, {3}, {3}, {3}, {2, 3}, {3}, {1, 2}, {1, 2, 3}, {3}]
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Best valset aggregate score so far: 0.7013888888888888
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Best program as per aggregate score on train_val: 3
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Best program as per aggregate score on valset: 3
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Best score on valset: 0.7013888888888888
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Best score on train_val: 0.7013888888888888
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: Linear pareto front program index: 3
# 2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 3: New program candidate index: 3
# GEPA Optimization:  46%|████▌     | 54/117 [03:32<04:08,  3.94s/rollouts]2025/09/17 10:01:10 INFO dspy.teleprompt.gepa.gepa: Iteration 4: Selected program 3 score: 0.7013888888888888
# Average Metric: 2.12 / 3 (70.8%): 100%|██████████| 3/3 [00:24<00:00,  8.15s/it]
# 2025/09/17 10:01:35 INFO dspy.evaluate.evaluate: Average Metric: 2.125 / 3 (70.8%)
# 2025/09/17 10:06:03 INFO dspy.teleprompt.gepa.gepa: Iteration 4: Proposed new text for self: Task:
# From free-form invoice text, extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Strict output format:
# - Return a single JSON object only (no wrapper, no comments, no rationale).
# - Include exactly these 8 keys (all 8 must be present, even if unknown), with string values only, in this exact order:
#   1) company
#   2) billed_to
#   3) invoice_number
#   4) invoice_date
#   5) total_amount
#   6) bank_name
#   7) account_name
#   8) account_number
# - If a field is not present in the text, set it to "" (empty string).
# - Do not include any extra keys (no addresses, emails, line items, notes, etc.).
#
# General extraction principles:
# - Be case-insensitive for label detection (e.g., “INVOICE NO”, “invoice no”, “Invoice No”).
# - Labels and values can be split across adjacent lines; associate them by proximity, order, and plausibility (e.g., bank names are alphabetic words; account numbers are numeric/alphanumeric).
# - When multiple candidates exist for the same field, choose the one that is:
#   1) Closest to its label.
#   2) Most explicitly and clearly labeled.
#   3) For totals, the final, bottom-most grand total.
# - Strip surrounding whitespace and trailing punctuation from extracted values. Preserve internal formatting (e.g., keep currency symbols, thousands separators, hyphens, and spaces in IDs and account numbers), but remove any trailing non-value tokens accidentally glued to the value (e.g., “23 March 2025INVOICE” → “23 March 2025”).
# - Prefer issuer/company names over individual names when both appear for the same role, unless a payee/pay-to block explicitly names the issuer as an individual.
#
# Field definitions, synonyms, and tie-breakers:
#
# 1) company (issuer/seller sending the invoice)
# - Primary sources (priority order):
#   a) A distinct issuer/payee block labeled with any of: “PAY TO:”, “Pay to:”, “Payable to:”, “Make checks payable to:”, “Make payment to:”, “Remit to:”, “Remittance to:”, “Beneficiary:”, “Vendor:”, “Seller:”, “From:”, “Service Provider:”, “Company:”, “Supplier:”.
#   b) The most prominent brand/header name near the main “INVOICE” title (ignore generic template words like “Invoice Template”, “Professional Service Invoice”).
# - If both a person and a company name appear together for the issuer, prefer the company name (e.g., choose “Wardi LLC” over “Olivia Wilson”).
# - If there is a distinct “PAY TO”/“Payable to” block, treat the entity named there as the issuer; prefer the company name in that block if present. If only a person is named there and no clear company is tied to that pay-to block, use the person’s name as company.
# - Special caution for misleading “Customer:” lines:
#   - If the only named organization appears under a “Customer:” label but the surrounding details clearly belong to the service provider/issuer (e.g., the email domain matches the name, the bank/account details match that name, or there is no other party indicated), treat that name as the issuer company and do NOT use it as billed_to.
# - Value must be just the name (exclude addresses, phones, emails, URLs, tags like “Agency”, unless they are part of the official name).
#
# 2) billed_to (customer/recipient being invoiced)
# - Look for labels: “Bill To”, “Billed To”, “Invoice To”, “Customer”, “Client”, “Ship To” (if clearly used as billing/customer), “Sold To”, “Recipient”, “Attention”.
# - If both a company and a person appear under the billed-to label, prefer the company name; otherwise use a person’s name if that’s all that’s available.
# - If no explicit billed-to label exists but two distinct parties are clearly indicated (e.g., an issuer/payee block and another party with address/contact details), infer billed_to as the non-issuer party’s name (use the name line only).
# - Do not infer a billed_to if only one party is present; in that case, set billed_to to "".
# - Use only the name (no address, phone, or email).
#
# 3) invoice_number
# - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO:”, “Invoice no:”, “Inv No”, “Inv #”, “Invoice Code”.
# - Also accept a stand-alone “#<number>” near the invoice header info (strip the leading “#”).
# - Preserve the identifier exactly, including hyphens and leading zeros (e.g., “INV-00001”, “2000-15”, “001”).
# - Remove label text and any trailing punctuation or glued words (e.g., “12345INVOICE” → “12345”).
#
# 4) invoice_date
# - The invoice date (not service date, not due date).
# - Prefer labels like: “Invoice Date”, “DATE:”, “Date of Issue”, “DATE OF ISSUE”, “Issued on”.
# - If only a generic “Date” appears near the invoice header info (adjacent to “Invoice No/ID” etc.), use that.
# - Exclude “Due Date”, “Payment Date”, “Service Date”, “Delivery Date”.
# - Keep the original formatting (e.g., “01/01/2023”, “15/08/2028”, “11.02.2030”, “23 March 2025”). If extra non-date tokens are stuck to the end (e.g., “…INVOICE”), trim them off.
#
# 5) total_amount (grand total due)
# - Prefer explicit grand-total labels such as: “TOTAL”, “TOTAL AMOUNT”, “TOTAL AMOUNT DUE”, “Amount Due”, “Balance Due”, “Grand Total”.
# - Do not use subtotal, tax, or partial totals.
# - If multiple totals are present, choose the final grand total, typically the bottom-most value after taxes/discounts or the value emphasized in a total/amount-due box.
# - Preserve currency symbols and formatting exactly as shown (e.g., “$625.00”, “$ 346.50”, “€1.234,56”, “$1.100”).
#
# 6) bank_name
# - The bank’s name where payment should be made.
# - Look for labels: “Bank Name”, “Bank:”, “Bank”.
# - Use a textual bank name (alphabetic words). Do NOT take numeric strings or bank codes as the bank name. Do NOT use “Bank Code”.
# - If “Bank:” appears but the value is on an adjacent line (above or below), use the nearest textual bank name.
# - In multi-line stacked label/value blocks, match in order (see “Stacked/misaligned labels” below).
#
# 7) account_name
# - The name on the bank account.
# - Look for labels: “Account Name”, “Acct. Name”, “Account Holder”, “Beneficiary”, “Beneficiary Name”, “Payee”.
# - Use only the name (no bank, no extra lines). Preserve original casing as in the text.
#
# 8) account_number
# - The bank account number.
# - Look for labels: “Account Number”, “Account No”, “Acct No”, “Acct. No.”, “Account #”, “A/C No”, “A/C #”, “IBAN” (use IBAN if it’s the only account number provided), “Account”.
# - Preserve formatting (keep spaces/dashes: e.g., “123-456-7890”, “0123 4567 8901”, “GB29 NWBK 6016 1331 9268 19”).
# - Prefer values that are clearly numeric/alphanumeric identifiers over words or phone numbers; rely on nearby labels to disambiguate.
#
# Disambiguation and edge cases:
#
# - Stacked/misaligned labels:
#   - Some templates stack labels on separate lines and put values on following lines with colons, e.g.:
#     Bank
#     Name
#     Account
#     : Fauget Bank
#     : Pedro fernandez
#     : 0123 4567 8901
#   - In such cases, treat “Bank Name Account” as an ordered list of labels and assign values in order: bank_name = first value (textual bank), account_name = second value (name-like), account_number = third value (numeric/alphanumeric).
#   - When a repeated generic label like “Account” appears for both name and number, decide by value type: alphabetic name-like → account_name; numeric/alphanumeric → account_number.
#
# - PAY TO vs header brand:
#   - If a distinct “PAY TO/Payable to/Remit to/Beneficiary” block exists, treat that entity as the issuer (company), even if a different brand appears near the “INVOICE” header. Prefer a company name over a person in that block if both appear; otherwise use the person.
#   - If no pay-to/issuer block exists, use the prominent brand near “INVOICE”.
#   - Do not treat generic decorative headings (e.g., “Professional Service Invoice”, “Invoice Template”) as company names.
#
# - “Customer” ambiguity:
#   - Use “Customer/Client/Bill To” as billed_to only if there is a clear issuer identified elsewhere.
#   - If “Customer:” is the only named entity but the surrounding contact/bank/email clearly belong to that same entity (i.e., it appears to be the issuer), use it as company and leave billed_to = "".
#
# - Dates glued to words:
#   - If a date value has extra trailing tokens (e.g., “23 March 2025INVOICE”), strip the non-date suffix to keep only the date.
#
# - Totals:
#   - Use the final, grand total amount (often bottom-most, or explicitly “Amount Due”/“TOTAL” box).
#   - Do not compute totals unless the grand total is explicitly shown; if a grand total value is present, use it as-is (currency and separators preserved).
#
# - Cleaning and formatting:
#   - Trim surrounding spaces and trailing punctuation (e.g., trailing colon, period) from extracted values.
#   - Preserve internal formatting of IDs and amounts exactly as shown.
#   - Remove a leading “#” from invoice_number values (e.g., “#91028829” → “91028829”).
#
# If a field cannot be confidently identified following the above rules, set it to "".
#
# Return only the JSON object with the 8 required keys and string values, nothing else.
# 2025/09/17 10:06:36 INFO dspy.evaluate.evaluate: Average Metric: 2.125 / 3 (70.8%)
# 2025/09/17 10:06:36 INFO dspy.teleprompt.gepa.gepa: Iteration 4: New subsample score is not better, skipping
# GEPA Optimization:  51%|█████▏    | 60/117 [08:58<10:17, 10.83s/rollouts]2025/09/17 10:06:36 INFO dspy.teleprompt.gepa.gepa: Iteration 5: Selected program 2 score: 0.6597222222222222
# Average Metric: 2.12 / 3 (70.8%): 100%|██████████| 3/3 [00:36<00:00, 12.17s/it]
# 2025/09/17 10:07:12 INFO dspy.evaluate.evaluate: Average Metric: 2.125 / 3 (70.8%)
# 2025/09/17 10:12:33 INFO dspy.teleprompt.gepa.gepa: Iteration 5: Proposed new text for self: Task
# From free-form invoice text (plain text), extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Input
# - A single block of plain text containing an invoice (often messy, with headers, labels, placeholders, totals, and bank/payment details).
# - Many inputs are mockups/templates with placeholder text. Never guess; only extract values that are explicitly present and clearly tied to labels.
#
# Output format
# - Return exactly one JSON object (not wrapped, no comments, no rationale).
# - Use double quotes for all keys and string values.
# - Include exactly these 8 keys (all must be present, even if unknown), with string values:
#   1) "company"
#   2) "billed_to"
#   3) "invoice_number"
#   4) "date"
#   5) "total_amount"
#   6) "bank_name"
#   7) "account_name"
#   8) "account_number"
# - If a field is not present in the text, set it to "" (empty string).
# - Do not include any extra keys or metadata. Do not rename any keys.
#
# General extraction strategy
# - Prioritize clearly labeled fields. Prefer values explicitly tied to labels over inferred or stylistic text.
# - When multiple candidates exist, pick the one closest to the relevant label. Do not search far away from the label; if a nearby value is not present, leave the field empty.
# - Preserve the exact formatting of extracted values:
#   - Keep currency symbols, spaces, and thousands separators (e.g., "$ 2,000.00", "€1.234,56").
#   - Keep leading zeros and prefix characters in IDs (e.g., "#01234", "INV-00008").
#   - Keep spaces/dashes in account numbers (e.g., "123-456-7890", "0123 4567 8901").
# - Never fabricate values. If not explicitly present, return "".
#
# Field-specific rules and pitfalls
#
# 1) company (issuer/seller)
# - Look for (in this order):
#   a) Explicit issuer blocks: “From”, “FROM:”, “Seller”, “Vendor”, “Supplier”, “Issued by”, “Company”, “PAY TO” / “Pay To”.
#   b) Role labels identifying the issuer, e.g., “Freelancer: <name>”, “Consultant: <name>”.
#   c) A prominent brand/company name near the invoice header only if it clearly denotes a real entity and not a template/theme/slogan.
# - Do NOT use template/theme titles or generic headings as the company. Examples to ignore:
#   - “Green IT Company Professional Service Invoice”
#   - “White Minimalist Business Invoice”
#   - “Really Great Company” when used as placeholder/slogan (e.g., “Your Business Partner”)
#   - “Your Logo”, “reallygreatsite.com”, other obvious placeholders
# - If both a company and a person are listed in the issuer block, prefer the company. If only a person appears, use the person’s name.
# - Extract only the name line; exclude address, phone, email, URLs.
#
# 2) billed_to (customer/recipient)
# - Look for labels: “Bill To”, “Billed To”, “Invoice To”, “INVOICE TO”, “Issued to”, “Customer”, “Client”, “To:”.
# - Prefer the company name if both a company and a contact person are listed; otherwise use the person’s name.
# - Extract only the name line; exclude address/phone/email/URLs.
# - Important: “PAY TO” indicates the issuer (company), NOT the customer. Do not use “PAY TO” for billed_to.
# - Proximity rule: If the “Bill To/Invoice To/Issued to” label does not have a clearly adjacent name, do not pick a distant name elsewhere; leave billed_to as "".
#
# 3) invoice_number
# - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO.”, “No:” when clearly part of the invoice metadata.
# - Also accept a standalone “#12345” near the invoice header when it clearly serves as the invoice number.
# - Extract exactly as shown, preserving hyphens, leading zeros, and prefix characters (e.g., “#01234”, “INV-00008”, “2000-15”, “001”).
# - Ensure the value is truly tied to the invoice identifier label/cluster, not a generic “No.” used for other purposes.
#
# 4) date (invoice date)
# - Prefer labels: “Invoice Date”, “Date of Issue”, “Issue Date”, “Date”, “Date Issued”.
# - Do NOT use “Service Date”, “Due Date”, or “Payment Date”.
# - If only an unlabeled date appears near the invoice header/number and no other date types are present, use it as the invoice date.
# - Preserve original formatting (e.g., “08/01/2023”, “15/01/2028”, “5 December 2030”).
#
# 5) total_amount (grand total due)
# - Prefer final total labels: “TOTAL”, “TOTAL AMOUNT DUE”, “TOTAL AMOUNT”, “Amount Due”, “Balance Due”, “GRAND TOTAL”, “Total :”.
# - Choose the total from the summary/totals section (often near the end, alongside “Sub-total”, “Tax”, “Discount”), not line-item totals.
# - If conflicting totals exist (e.g., a big “TOTAL DUE $12345” near a header vs. a calculated “Total : $1,680” in the summary block), pick the one in the summary/totals block that aligns with sub-total/tax lines. Avoid decorative/header numbers.
# - Preserve currency symbol and spacing exactly as shown (e.g., “$ 0.00”, “$123.45”, “€1.234,56”).
#
# 6) bank_name
# - Look for “Bank Name:”, “Bank:”, or a standalone bank line within a “Bank Details/Bank Information/Payment Information” block.
# - Use the explicitly provided value even if it looks like a person’s name (e.g., “Bank Name: Francisco Andrade”)—labels take precedence.
# - Do NOT use placeholders or empty labels (e.g., “Bank:”, “No Bank:”, “Name Bank”)—if no real value is given, return "".
# - Do NOT use “Bank Code” as bank_name.
#
# 7) account_name
# - Look for “Account Name”, “Account Holder”, “Beneficiary Name” inside bank/payment details.
# - Use only explicitly labeled values; do not infer from issuer/customer names unless the label clearly ties them.
#
# 8) account_number
# - Look for “Account Number”, “Account No”, “Acct No”, “A/C No”, “AC No.”, “A/C #”, “Bank Account”.
# - Preserve formatting (retain spaces/dashes), e.g., “123-456-7890”, “0123 4567 8901”.
# - If only IBAN is provided and no separate account number is present, use the IBAN (preserve its formatting).
# - Do NOT use routing numbers, bank codes, or SWIFT/BIC as account_number.
#
# Disambiguation and edge cases
# - Template/theme headings: Ignore descriptive titles like color/style (“White Minimalist Business Invoice”, “Beige Elegant Professional Business Invoice”, “Professional Service Invoice”). These are not company names.
# - Slogans and placeholders (e.g., “Your Business Partner”, “Your Logo”, “reallygreatsite.com”) are not company names.
# - Role titles like “Administrator”, “Manager Company”, “Finance Manager” are roles, not company names. Do not output the role text; only extract a clearly labeled company/person if it denotes the issuer.
# - Multi-line blocks: When a block contains name + address, extract only the name line for company or billed_to.
# - Conflicting or duplicated numbers (e.g., the same digits appearing as invoice number and bank account): treat each field independently based on its own label.
# - If a clearly labeled bank detail contradicts other roles (e.g., bank_name equals a person’s name), still extract the labeled value as-is.
# - If a field cannot be confidently located, set it to "".
#
# Final output
# - Return exactly one JSON object with the 8 keys and string values, nothing else.
# 2025/09/17 10:13:12 INFO dspy.evaluate.evaluate: Average Metric: 2.125 / 3 (70.8%)
# 2025/09/17 10:13:12 INFO dspy.teleprompt.gepa.gepa: Iteration 5: New subsample score is not better, skipping
# GEPA Optimization:  56%|█████▋    | 66/117 [15:34<16:52, 19.86s/rollouts]2025/09/17 10:13:12 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Selected program 2 score: 0.6597222222222222
# Average Metric: 2.00 / 3 (66.7%): 100%|██████████| 3/3 [00:47<00:00, 15.92s/it]
# 2025/09/17 10:13:59 INFO dspy.evaluate.evaluate: Average Metric: 2.0 / 3 (66.7%)
# 2025/09/17 10:15:23 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Proposed new text for self: Task
# From free-form invoice text (plain text), extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
# Input
# - A single string that contains the full invoice text. The text may be noisy, include template/branding phrases, and may present fields in any order.
#
# Output format
# - Return exactly one JSON object (not wrapped in an array; no comments, no rationale).
# - Include exactly these 8 keys with string values (all keys must be present, even if the value is unknown):
#   1) "company"
#   2) "billed_to"
#   3) "invoice_number"
#   4) "invoice_date"
#   5) "total_amount"
#   6) "bank_name"
#   7) "account_name"
#   8) "account_number"
# - If a field is not explicitly present in the text, set its value to "" (empty string).
# - Do not include any extra keys or metadata. Do not rename any keys.
#
# General extraction strategy
# - Prioritize clearly labeled fields. Prefer values explicitly tied to a label over inferred or stylistic text.
# - When multiple candidates exist for a field, choose the value closest to the most relevant label.
# - Preserve the exact formatting of extracted values:
#   - Keep currency symbols, thousands separators, spacing, and decimal punctuation in amounts.
#   - Keep any prefix characters and formatting in IDs (e.g., “#01234”, “INV-00008”, “2000-15”).
#   - Keep spaces/dashes in account numbers and IBANs as shown.
# - Never fabricate values. If a field is not explicitly available, return "".
# - Extract only the name for party fields (no addresses, phones, emails, or URLs).
#
# Field-specific rules
#
# 1) company (the issuing/seller entity)
# - Look in this order:
#   a) Explicit issuer blocks/labels: “From”, “FROM:”, “Seller”, “Vendor”, “Supplier”, “Issued by”, “Company”, “PAY TO” / “Pay To”, “Service Provider”, “Freelancer: <name>”, “Consultant: <name>”.
#   b) Prominent company/person name near the invoice header only if it clearly denotes a real entity (not a template/theme descriptor).
# - Prefer the company name if both a company and a person appear in the issuer block; if only a person appears, use that person’s name.
# - Extract only the name line (omit address/contact).
# - Do NOT use template/theme/descriptor titles as the company, such as:
#   - “Beige Gray Simple Minimalist Consultation Invoice”
#   - “Green IT Company Professional Service Invoice”
#   - “Pink Modern Service Invoice”
#   - “Freelance Invoice Template”
#   These are not company names.
#
# 2) billed_to (the customer/recipient being invoiced)
# - Look for: “Bill To”, “Billed To”, “Invoice To”, “Customer”, “Client”, “To:”, “ISSUED TO:”.
# - Prefer the customer company name over a contact person if both are present; if only a person is present, use the person’s name.
# - Extract only the name line (omit address/contact).
# - Important: “PAY TO” (or “Pay To”) denotes the issuer (company), NOT the customer. Do not use “PAY TO” for billed_to.
#
# 3) invoice_number
# - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO.”, “INVOICE NO:”, “INVOICE ID:”.
# - Also accept a standalone “#12345” near the invoice header when clearly serving as the invoice number.
# - Preserve the exact formatting, including prefixes, leading zeros, separators, and “#” if present.
#
# 4) invoice_date (the invoice issue date)
# - Prefer labels: “Invoice Date”, “Date of Issue”, “Issue Date”, “DATE:”, “Date”.
# - Do NOT use “Service Date”, “Due Date”, or “Payment Date”.
# - If only an unlabeled date appears near the invoice header/number and no other date types are present, treat it as the invoice date.
# - Preserve the original formatting (e.g., “08/01/2023”, “11.02.2030”, “5 December 2030”).
#
# 5) total_amount (grand total due)
# - Prefer labels in the summary/totals section: “TOTAL”, “TOTAL AMOUNT DUE”, “TOTAL AMOUNT”, “Amount Due”, “Balance Due”, “Grand Total”, “Total Amount”.
# - Choose the final payable total from the summary block (often at or near the end), not a line-item total.
# - Do NOT use “Sub-Total”, “Subtotal”, “Tax”, “Discount”, or intermediate sums.
# - If multiple total-like amounts exist:
#   - Prefer “Amount Due”, “Total Amount”, “Grand Total”, “Balance Due” over a generic “Total” if both are present.
#   - Ignore percentages or rates (e.g., lines with “10%”).
#   - Pick the amount nearest to the clearest total label within the summary block.
#
# 6) bank_name
# - Look for “Bank Name:”, “Bank:”, or an unlabeled bank name line within a “Bank Details/Bank Information” section.
# - Do NOT return “Bank Code” or routing numbers as the bank_name unless the actual bank name is explicitly provided.
#
# 7) account_name
# - Look for “Account Name”, “Account Holder”, “Beneficiary Name” within payment/bank details.
# - Use only explicitly labeled values; do not infer from unrelated context or roles.
#
# 8) account_number
# - Look for “Account Number”, “Account No”, “Acct No”, “A/C No”, “AC No.”, “A/C #”.
# - Preserve formatting (retain spaces/dashes), e.g., “123-456-7890”, “0123 4567 8901”.
# - If only an IBAN is provided and no separate account number is present, use the IBAN as account_number (preserve its formatting).
# - Do NOT use routing numbers, bank codes, or SWIFT/BIC as account_number.
#
# Disambiguation and edge cases
# - Template/theme headings are NOT company names. Ignore stylistic/descriptor titles even if they contain industry terms (e.g., “Green IT Company Professional Service Invoice”).
# - “Freelancer: <name>”, “Service Provider”, “PAY TO”, and “From” typically indicate the issuer (company).
# - “ISSUED TO”, “Bill To”, “Client/Customer” indicate the recipient (billed_to).
# - Multi-line blocks: when a block contains name + address/contact, extract only the name line for company or billed_to.
# - If a clearly labeled bank detail coincides with a party name (e.g., account_name equals the customer), still extract the labeled bank fields as shown; do not reinterpret roles.
# - If a field cannot be confidently located, set it to "".
#
# Validation before output
# - Ensure all 8 keys are present with string values.
# - Ensure invoice_date is used as the date key (not “date” or any other variant).
# - Preserve exact source formatting for all extracted values.
# - Return only the JSON object, with no extra commentary.
# 2025/09/17 10:15:51 INFO dspy.evaluate.evaluate: Average Metric: 2.1875 / 3 (72.9%)
# 2025/09/17 10:16:51 INFO dspy.evaluate.evaluate: Average Metric: 6.4375 / 9 (71.5%)
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: New program is on the linear pareto front
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Full valset score for new program: 0.7152777777777778
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Full train_val score for new program: 0.7152777777777778
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Individual valset scores for new program: [0.6875, 0.6875, 0.8125, 0.5625, 0.875, 0.625, 0.75, 0.6875, 0.75]
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: New valset pareto front scores: [0.6875, 0.6875, 0.8125, 0.625, 0.875, 0.6875, 0.75, 0.6875, 0.75]
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Full valset pareto front score: 0.7291666666666666
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Updated valset pareto front programs: [{3, 4}, {3, 4}, {3, 4}, {3}, {4}, {3}, {4}, {4}, {3, 4}]
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Best valset aggregate score so far: 0.7152777777777778
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Best program as per aggregate score on train_val: 4
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Best program as per aggregate score on valset: 4
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Best score on valset: 0.7152777777777778
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Best score on train_val: 0.7152777777777778
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: Linear pareto front program index: 4
# 2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 6: New program candidate index: 4
# GEPA Optimization:  69%|██████▉   | 81/117 [19:14<10:45, 17.94s/rollouts]2025/09/17 10:16:51 INFO dspy.teleprompt.gepa.gepa: Iteration 7: Selected program 3 score: 0.7013888888888888
# Average Metric: 2.12 / 3 (70.8%): 100%|██████████| 3/3 [00:22<00:00,  7.66s/it]
# 2025/09/17 10:17:14 INFO dspy.evaluate.evaluate: Average Metric: 2.125 / 3 (70.8%)
# 2025/09/17 10:20:38 INFO dspy.teleprompt.gepa.gepa: Iteration 7: Proposed new text for self: Task:
# ...
# - Preserve the currency symbol and number formatting (e.g., “$625.00”, “$ 346.50”, “€1.234,56”).
# - Ignore subtotal, tax, or intermediate totals, and ignore stray amounts near “Terms & Conditions” unless directly tied to a grand total label.
#
# 6) bank_name
# - The bank’s name where payment should be made.
# - Look for “Bank Name”, “Bank:”.
# - Prefer alphabetic bank names; do NOT use numeric strings/codes or “Bank Code” as the bank name.
# - If the name is on an adjacent line, associate the nearest plausible bank name.
# - Normalize whitespace and fix obvious OCR splits (e.g., “Thynk Unl imited Bank” → “Thynk Unlimited Bank”).
#
# 7) account_name
# - The name on the bank account.
# - Look for “Account Name”, “Acct. Name”, “Account Holder”, “Beneficiary”.
# - Use the textual name only (no addresses/notes).
#
# 8) account_number
# - The bank account number.
# - Look for “Account Number”, “Account No”, “Acct No”, “Acct. No.”, “Account #”, “A/C No”, “A/C #”, “IBAN” (if this is the only account number), or “Bank Account” when it clearly denotes the account number.
# - Preserve formatting (spaces/dashes) exactly as shown (e.g., “123-456-7890”, “0123 4567 8901”, “DE89 3704 0044 0532 0130 00”).
# - Heuristics to avoid phones/miscodes:
#   - Prefer numbers under explicit account labels over unlabeled numbers.
#   - If a number matches a phone pattern and also appears elsewhere as a phone, avoid using it unless it is the only value under a clear bank account label.
#   - Prefer longer account/IBAN-like strings when multiple candidates exist.
#
# Disambiguation and tricky layouts:
# - Handle concatenated labels/values caused by OCR:
#   - “INVOICEBorcelle” → treat as label “INVOICE” + company “Borcelle”.
#   - “INVOICE TOCOMPANY:” → two labels; map values accordingly (billed_to after “INVOICE TO”, issuer after “COMPANY”).
#   - “$8987TOTAL” or “$ 8987TOTAL” → extract “$8987” / “$ 8987” as total_amount.
# - Issuer vs customer conflicts:
#   - If a “Customer”/“Bill To” is present and the same name also appears as “Account Name” in bank details, treat that name as billed_to. Do NOT also assign it to company unless there is an explicit issuer block that clearly indicates the same entity is the seller; otherwise set company to "".
#   - When a “PAY TO:” block lists both a person and a company, choose the company as issuer.
# - Avoid template placeholders:
#   - Do not set company to generic template branding (e.g., “Trucking Invoice Template”, “Proforma Invoice Template”). If no distinct issuer is present, leave company as "".
# - If no explicit billed_to exists but two distinct parties appear (e.g., one near “PAY TO:” and another near an address), infer billed_to as the non-issuer party; otherwise leave billed_to as "".
#
# Always output exactly:
# {"company":"...","billed_to":"...","invoice_number":"...","invoice_date":"...","total_amount":"...","bank_name":"...","account_name":"...","account_number":"..."}
# 2025/09/17 10:25:06 INFO dspy.evaluate.evaluate: Average Metric: 2.5 / 3 (83.3%)
# 2025/09/17 10:26:16 INFO dspy.evaluate.evaluate: Average Metric: 6.4375 / 9 (71.5%)
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Full valset score for new program: 0.7152777777777778
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Full train_val score for new program: 0.7152777777777778
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Individual valset scores for new program: [0.6875, 0.6875, 0.75, 0.625, 0.8125, 0.6875, 0.6875, 0.75, 0.75]
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: New valset pareto front scores: [0.6875, 0.6875, 0.8125, 0.625, 0.875, 0.6875, 0.75, 0.75, 0.75]
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Full valset pareto front score: 0.7361111111111112
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Updated valset pareto front programs: [{3, 4, 5, 6}, {3, 4, 5, 6}, {3, 4, 5}, {3, 5, 6}, {4}, {3, 5, 6}, {4}, {6}, {3, 4, 5, 6}]
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Best valset aggregate score so far: 0.7152777777777778
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Best program as per aggregate score on train_val: 4
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Best program as per aggregate score on valset: 4
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Best score on valset: 0.7152777777777778
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Best score on train_val: 0.7152777777777778
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: Linear pareto front program index: 4
# 2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 8: New program candidate index: 6
# GEPA Optimization:  95%|█████████▍| 111/117 [28:38<01:49, 18.27s/rollouts]2025/09/17 10:26:16 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Selected program 6 score: 0.7152777777777778
# Average Metric: 2.31 / 3 (77.1%): 100%|██████████| 3/3 [00:33<00:00, 11.12s/it]
# 2025/09/17 10:26:49 INFO dspy.evaluate.evaluate: Average Metric: 2.3125 / 3 (77.1%)
# 2025/09/17 10:29:17 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Proposed new text for self: Task
# Extract a small, fixed set of top-level invoice fields from free-form invoice text (often noisy/OCR’d) and return them as a flat JSON object.
#
# Input
# - A single block of raw invoice text (may contain OCR errors, concatenated labels/values, missing spaces, and mixed order).
#
# Output (strict)
# - Return a single JSON object only (no wrapper text, comments, or rationale).
# - Include exactly these 8 keys (all must be present), with string values (use "" if unknown):
#   1) company
#   2) billed_to
#   3) invoice_number
#   4) invoice_date
#   5) total_amount
#   6) bank_name
#   7) account_name
#   8) account_number
# - Do not include any extra keys.
#
# General approach and normalization
# - Prefer clearly labeled fields and the most explicit indicators. Associate labels and values across adjacent lines and across OCR-concatenations (e.g., “INVOICEBorcelle” → label “INVOICE” + value “Borcelle”).
# - If a field is truly not present, output "" (empty string). Do not guess or infer from unrelated sections.
# - Normalize values:
#   - Trim leading/trailing spaces.
#   - Collapse multiple internal spaces into a single space.
#   - Remove trailing punctuation after values (e.g., trailing commas/periods/colons).
#   - Remove a leading “#” from identifiers.
#   - Repair obvious OCR splits within words for names (e.g., “Unl imited” → “Unlimited”, “Appl ication” → “Application”).
#   - Preserve original numeric formatting for IDs, dates, and currency (keep hyphens, leading zeros, spaces, separators, and currency symbol). For currency totals, prefer the exact formatted number adjacent to the accepted total label.
#
# Field definitions, priorities, and decision rules
#
# 1) company (issuer/seller sending the invoice)
# - Strong signals for issuer (in priority order):
#   1. A “PAY TO:” or “Beneficiary” block that clearly identifies the payee entity. If both a person and a company appear, choose the company (e.g., prefer “Wardi LLC” over “Olivia Wilson”).
#   2. An explicit issuer block: labels like “From”, “FROM:”, “Seller”, “Vendor”, “Company”, “Service Provider”, “PAY TO:”.
#   3. A prominent brand/company name near the large “INVOICE” header (handle OCR concatenations: e.g., “INVOICEBorcelle” → company “Borcelle”).
# - If there is no explicit issuer under the labels above AND there is a clear “Account Name”/“Beneficiary” in the bank details, you may use that as the issuer (tie-breaker).
# - Important constraints:
#   - Never override an explicit “Customer”/“Bill To” with the bank “Account Name” if they are the same string. In that case, set billed_to to that customer name and leave company as "" unless another distinct issuer is present.
#   - Do not set company and billed_to to the same value unless the document explicitly presents the same entity as both issuer and customer under clear role labels (rare). If ambiguous, prefer company = "" and keep billed_to from the customer label.
#   - Do NOT pick generic template headers as the issuer (e.g., “Consulting Invoice Template”, “Professional Service Invoice”, “Construction Invoice Template”, “Proforma Invoice Template”, “Green IT Company Professional Service Invoice”).
#   - Do not infer issuer solely from an unlabeled standalone name/address unless (a) no stronger issuer signals exist, and (b) it is clearly styled or positioned as the brand/company near the main INVOICE header.
#
# 2) billed_to (customer/recipient being invoiced)
# - Look for labels: “Bill To”, “Billed To”, “Invoice To”, “INVOICE TO”, “Customer”, “Client”, “Ship To” (only when clearly used as the billing/customer context).
# - If both a company and a person appear under this label, prefer the company; else use the person’s name.
# - If “INVOICE TO” and “COMPANY” appear close together (even if concatenated, e.g., “INVOICE TOCOMPANY:”):
#   - Map the entity following “INVOICE TO” to billed_to.
#   - Map the entity following “COMPANY” to the issuer (company).
# - If no explicit billed-to label exists but two distinct parties clearly appear (issuer and the other party with address/contact lines), infer billed_to as the non-issuer party (name only).
# - Do NOT derive billed_to from a “PAY TO:”/beneficiary/payment block; those indicate the issuer/payee, not the customer. If there is no explicit customer and only issuer/payee details are present, set billed_to to "".
# - Use the name only (no address/phone/email).
#
# 3) invoice_number
# - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO:”, “NO.” near the invoice header/info block.
# - Also accept patterns like “#12345” near the header; remove the leading “#”.
# - Extract the identifier exactly, preserving hyphens, letters, and leading zeros (e.g., “INV-00001”, “2000-15”, “001”).
# - Do not include label text or trailing punctuation.
#
# 4) invoice_date
# - The invoice issue date (not due date, not service date).
# - Prefer labels in this order when values differ:
#   1. “Invoice Date”
#   2. “Date of Issue” / “DATE OF ISSUE”
#   3. A generic “Date” only when it appears within the invoice header/info block and is clearly the issue date.
# - Do NOT use “Due Date”, “DUE”, “Service Date”.
# - Keep the original date format/order as shown; normalize spacing around separators (e.g., “01 / 02 / 2023” → “01/02/2023”).
#
# 5) total_amount (grand total due)
# - Prefer explicit grand total labels: “Amount Due”, “Balance Due”, “TOTAL”, “TOTAL:”, “TOTAL AMOUNT”, “TOTAL AMOUNT DUE”, “Grand Total”, “Total”.
# - When multiple totals are present, choose the final, bottom-most grand total after taxes/discounts. Example: if “Total Amount $2500.00” appears earlier but a later “Total”/“Amount Due” shows “$2000.00”, pick “$2000.00”.
# - Preserve the currency symbol and number formatting as shown (e.g., “$625.00”, “$ 346.50”, “€1.234,56”).
# - Ignore subtotal, tax, or intermediate totals, and ignore amounts near “Terms & Conditions” unless directly tied to a grand total label.
# - Handle OCR concatenations: “$8987TOTAL” or “$ 8987TOTAL” → extract “$8987” / “$ 8987” as total_amount.
#
# 6) bank_name
# - The bank’s name where payment should be made.
# - Look for “Bank Name”, “Bank:”.
# - Prefer alphabetic bank names; do NOT use numeric strings/codes or “Bank Code” as the bank name.
# - If the name is on an adjacent line, associate the nearest plausible bank name.
# - Normalize whitespace and fix obvious OCR splits (e.g., “Thynk Unl imited Bank” → “Thynk Unlimited Bank”).
#
# 7) account_name
# - The name on the bank account.
# - Look for “Account Name”, “Acct. Name”, “Account Holder”, “Beneficiary”, “Name:” when clearly within the payment/bank section.
# - Use the textual name only (no addresses/notes).
#
# 8) account_number
# - The bank account number to be paid.
# - Look for “Account Number”, “Account No”, “Acct No”, “Acct. No.”, “Account #”, “A/C No”, “A/C #”, “IBAN” (if this is the only account number), or “Bank Account” when it clearly denotes the account number.
# - Preserve formatting (spaces/dashes) exactly as shown (e.g., “123-456-7890”, “0123 4567 8901”, “DE89 3704 0044 0532 0130 00”).
# - Heuristics to avoid phones/miscodes:
#   - Prefer numbers under explicit account labels over unlabeled numbers.
#   - If a number matches a phone pattern and also appears elsewhere as a phone, avoid using it unless it is the only value under a clear bank account label.
#   - Prefer longer account/IBAN-like strings when multiple candidates exist.
#
# Disambiguation and OCR handling
# - Handle concatenated labels/values caused by OCR:
#   - “INVOICEBorcelle” → label “INVOICE” + company “Borcelle”.
#   - “INVOICE TOCOMPANY:” → two labels; map values accordingly (billed_to after “INVOICE TO”, issuer after “COMPANY”).
#   - “$8987TOTAL” or “$ 8987TOTAL” → extract the currency value for total_amount.
# - Issuer vs customer conflicts:
#   - If a “Customer”/“Bill To” is present and the same name also appears as “Account Name” in bank details, treat that name as billed_to. Do NOT also assign it to company unless there is a distinct issuer elsewhere; otherwise set company to "".
#   - When a “PAY TO:”/beneficiary block lists both a person and a company, choose the company as issuer.
#   - Do not set billed_to from a “PAY TO:”/beneficiary block. If no customer is present, leave billed_to as "".
# - Avoid template placeholders:
#   - Do not set company to generic template branding (e.g., “Trucking Invoice Template”, “Proforma Invoice Template”).
# - If no explicit billed_to exists but two distinct parties appear (e.g., an issuer/payee and a different named party with address/contact lines), infer billed_to as the non-issuer party; otherwise leave billed_to as "".
#
# Always output exactly (example skeleton)
# {"company":"...","billed_to":"...","invoice_number":"...","invoice_date":"...","total_amount":"...","bank_name":"...","account_name":"...","account_number":"..."}
# 2025/09/17 10:29:48 INFO dspy.evaluate.evaluate: Average Metric: 2.375 / 3 (79.2%)
# 2025/09/17 10:30:52 INFO dspy.evaluate.evaluate: Average Metric: 6.25 / 9 (69.4%)
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Full valset score for new program: 0.6944444444444444
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Full train_val score for new program: 0.6944444444444444
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Individual valset scores for new program: [0.6875, 0.6875, 0.8125, 0.625, 0.8125, 0.625, 0.625, 0.625, 0.75]
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: New valset pareto front scores: [0.6875, 0.6875, 0.8125, 0.625, 0.875, 0.6875, 0.75, 0.75, 0.75]
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Full valset pareto front score: 0.7361111111111112
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Updated valset pareto front programs: [{3, 4, 5, 6, 7}, {3, 4, 5, 6, 7}, {3, 4, 5, 7}, {3, 5, 6, 7}, {4}, {3, 5, 6}, {4}, {6}, {3, 4, 5, 6, 7}]
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Best valset aggregate score so far: 0.7152777777777778
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Best program as per aggregate score on train_val: 4
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Best program as per aggregate score on valset: 4
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Best score on valset: 0.7152777777777778
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Best score on train_val: 0.7152777777777778
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: Linear pareto front program index: 4
# 2025/09/17 10:30:52 INFO dspy.teleprompt.gepa.gepa: Iteration 9: New program candidate index: 7
# GEPA Optimization:  95%|█████████▍| 111/117 [33:14<01:47, 17.97s/rollouts]
# 2025/09/17 10:30:52 INFO dspy.evaluate.evaluate: Average Metric: 6.4375 / 9 (71.5%)
# Optimized field accuracy on valid: EvaluationResult(score=71.53, results=<list of 9 results>)

# %%
# Evaluate the optimized program on validation set
opt_score = evaluate(optimized_program)
print("Optimized field accuracy on validation:", opt_score)
# Out:
# 2025/09/17 10:40:22 INFO dspy.evaluate.evaluate: Average Metric: 6.4375 / 9 (71.5%)
# Optimized field accuracy on validation: EvaluationResult(score=71.53, results=<list of 9 results>)

# %%
optimized_program.save("./invoice_program/", save_program=True)

# %%
print(valid_examples[0].text)
# Out:
# Yellow and Black Professional Company Invoice
#
# No Items Qty Price Total
# 1 Cement 50 $20.00 $1000.00
# 2 Pvc Pipe 10 $10.00 $100.00
# 3 Brick 10 $10.00 $100.00
# 4 Wood Board 10 $10.00 $100.00
# Taylor Alonso
# Ginyard International Bank
# Bank Code (123-456-7890)
# Total $1200.00
# INVOICE
# Ingoude
# Company
# Jonathan Patterson
# +123-456-7890
# Invoice to
# #123456789
# 3rd January 2024
# Payment Terms
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# THANK YOU

# %%
print(valid_examples[0].target)
# Out:
# {'invoice_number': '123456789', 'invoice_date': '2024-01-03', 'billed_to': 'Jonathan Patterson', 'company': 'Ingoude', 'total_amount': '1200', 'bank_name': 'Ginyard International Bank', 'account_name': '', 'account_number': ''}

# %%
# Quick demo on a random validation example
sample = valid_examples[0]
print("Sample comparison:")
print("\nINPUT TEXT:")
print("-" * 80)
print(sample.text[:300], "...")
print("-" * 80)

print("\nBASE MODEL PREDICTION:")
base_pred = extractor(text=sample.text)
print(f"Rationale: {base_pred.rationale}")
print("\nExtracted fields:")
for k,v in (base_pred.extracted or {}).items():
    print(f"{k:20s}: {v}")

print("\nOPTIMIZED MODEL PREDICTION:")
opt_pred = optimized_program(text=sample.text)
print(f"Rationale: {opt_pred.rationale}")
print("\nExtracted fields:")
for k,v in (opt_pred.extracted or {}).items():
    print(f"{k:20s}: {v}")

print("\nGROUND TRUTH:")
print("\nExtracted fields:")
for k,v in sample.target.items():
    print(f"{k:20s}: {v}")
# Out:
# Sample comparison:
#
# INPUT TEXT:
# --------------------------------------------------------------------------------
# Yellow and Black Professional Company Invoice
#
# No Items Qty Price Total
# 1 Cement 50 $20.00 $1000.00
# 2 Pvc Pipe 10 $10.00 $100.00
# 3 Brick 10 $10.00 $100.00
# 4 Wood Board 10 $10.00 $100.00
# Taylor Alonso
# Ginyard International Bank
# Bank Code (123-456-7890)
# Total $1200.00
# INVOICE
# Ingoude
# Company
# Jonathan  ...
# --------------------------------------------------------------------------------
#
# BASE MODEL PREDICTION:
# Rationale: Parsed the invoice text and extracted identifiable fields. Detected:
# - Vendor: "Yellow and Black Professional Company"
# - Invoice number: "#123456789"
# - Invoice date: "3rd January 2024" (ISO: 2024-01-03)
# - Line items (4): Cement, Pvc Pipe, Brick, Wood Board with qty, unit price, line totals
# - Calculated subtotal from line items: $1300.00
# - Total shown on invoice: $1200.00 (mismatch vs calculated subtotal)
# - Bank: "Ginyard International Bank" and "Bank Code (123-456-7890)"
# - Contacts / parties: "Ingoude Company" (Invoice to / billed party), "Jonathan Patterson" (+123-456-7890), "Taylor Alonso"
# - Payment terms text present (lorem ipsum)
#
# Extracted fields:
# vendor_name         : Yellow and Black Professional Company
# invoice_number      : #123456789
# invoice_date        : 2024-01-03 (3rd January 2024)
# billed_to           : Ingoude Company
# issuer_contact      : Jonathan Patterson
# issuer_phone        : +123-456-7890
# authorized_by       : Taylor Alonso
# bank_name           : Ginyard International Bank
# bank_code           : 123-456-7890
# payment_terms       : Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# currency            : USD
# subtotal            : $1300.00 (calculated from line items)
# total_due           : $1200.00 (as shown on invoice)
# discrepancy_note    : Sum of line item totals ($1300.00) does not match invoice total ($1200.00).
# items               : [{"line":"1","description":"Cement","quantity":"50","unit_price":"$20.00","total":"$1000.00"}, {"line":"2","description":"Pvc Pipe","quantity":"10","unit_price":"$10.00","total":"$100.00"}, {"line":"3","description":"Brick","quantity":"10","unit_price":"$10.00","total":"$100.00"}, {"line":"4","description":"Wood Board","quantity":"10","unit_price":"$10.00","total":"$100.00"}]
#
# OPTIMIZED MODEL PREDICTION:
# Rationale: Detected fields:
# - company: "Ingoude Company" — appears directly under the "INVOICE" header ("INVOICE\nIngoude\nCompany"), chosen as the issuing company (ignoring the template title at the top).
# - billed_to: "Taylor Alonso" — name present after the item list, taken as the customer/recipient.
# - invoice_number: "#123456789" — line immediately below "Invoice to".
# - invoice_date: "3rd January 2024" — date shown next to the invoice/recipient block.
# - total_amount: "$1200.00" — "Total $1200.00" in the totals area; amount preserved with currency symbol.
# - bank_name: "Ginyard International Bank" — explicit bank name shown near the top of the payment block.
# - account_name: "" — no explicit "Account Name" / "Account Holder" / "Beneficiary" label present.
# - account_number: "" — no explicit "Account Number" / "A/C No" or IBAN present; only "Bank Code (123-456-7890)" which is not an account number.
#
# Extracted fields:
# company             : Ingoude Company
# billed_to           : Taylor Alonso
# invoice_number      : #123456789
# invoice_date        : 3rd January 2024
# total_amount        : $1200.00
# bank_name           : Ginyard International Bank
# account_name        :
# account_number      :
#
# GROUND TRUTH:
#
# Extracted fields:
# invoice_number      : 123456789
# invoice_date        : 2024-01-03
# billed_to           : Jonathan Patterson
# company             : Ingoude
# total_amount        : 1200
# bank_name           : Ginyard International Bank
# account_name        :
# account_number      :

# %%
# Compare predictions with ground truth
print("\nField Comparison:")
print("-" * 80)
for field in sample.target.keys():
    gt_value = sample.target[field]
    opt_value = opt_pred.extracted.get(field, "MISSING")
    match = "✓" if gt_value == opt_value else "✗"
    print(f"{field:20s}: {match}")
    if match == "✗":
        print(f"  Ground truth: {gt_value}")
        print(f"  Prediction:   {opt_value}")
print("-" * 80)
# Out:
# Field Comparison:
# --------------------------------------------------------------------------------
# invoice_number      : ✗
#   Ground truth: 123456789
#   Prediction:   #123456789
# invoice_date        : ✗
#   Ground truth: 2024-01-03
#   Prediction:   3rd January 2024
# billed_to           : ✗
#   Ground truth: Jonathan Patterson
#   Prediction:   Taylor Alonso
# company             : ✗
#   Ground truth: Ingoude
#   Prediction:   Ingoude Company
# total_amount        : ✗
#   Ground truth: 1200
#   Prediction:   $1200.00
# bank_name           : ✓
# account_name        : ✓
# account_number      : ✓
# --------------------------------------------------------------------------------

# %%
# Show the last interaction for transparency
print("\nInspecting last prompt:")
optimized_program(text=sample.text)
dspy.inspect_history(n=1)
# Out:
# Inspecting last prompt:
#
#
#
#
# [2025-09-17T10:40:39.735766]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): Raw invoice text
# Your output fields are:
# 1. `rationale` (str): Brief reasoning, list detected fields
# 2. `extracted` (dict): JSON dict with dataset keys and string values
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## rationale ## ]]
# {rationale}
#
# [[ ## extracted ## ]]
# {extracted}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Task
#         From free-form invoice text (plain text), extract a small, fixed set of top-level invoice fields and return them as a flat JSON object.
#
#         Input
#         - A single string that contains the full invoice text. The text may be noisy, include template/branding phrases, and may present fields in any order.
#
#         Output format
#         - Return exactly one JSON object (not wrapped in an array; no comments, no rationale).
#         - Include exactly these 8 keys with string values (all keys must be present, even if the value is unknown):
#           1) "company"
#           2) "billed_to"
#           3) "invoice_number"
#           4) "invoice_date"
#           5) "total_amount"
#           6) "bank_name"
#           7) "account_name"
#           8) "account_number"
#         - If a field is not explicitly present in the text, set its value to "" (empty string).
#         - Do not include any extra keys or metadata. Do not rename any keys.
#
#         General extraction strategy
#         - Prioritize clearly labeled fields. Prefer values explicitly tied to a label over inferred or stylistic text.
#         - When multiple candidates exist for a field, choose the value closest to the most relevant label.
#         - Preserve the exact formatting of extracted values:
#           - Keep currency symbols, thousands separators, spacing, and decimal punctuation in amounts.
#           - Keep any prefix characters and formatting in IDs (e.g., “#01234”, “INV-00008”, “2000-15”).
#           - Keep spaces/dashes in account numbers and IBANs as shown.
#         - Never fabricate values. If a field is not explicitly available, return "".
#         - Extract only the name for party fields (no addresses, phones, emails, or URLs).
#
#         Field-specific rules
#
#         1) company (the issuing/seller entity)
#         - Look in this order:
#           a) Explicit issuer blocks/labels: “From”, “FROM:”, “Seller”, “Vendor”, “Supplier”, “Issued by”, “Company”, “PAY TO” / “Pay To”, “Service Provider”, “Freelancer: <name>”, “Consultant: <name>”.
#           b) Prominent company/person name near the invoice header only if it clearly denotes a real entity (not a template/theme descriptor).
#         - Prefer the company name if both a company and a person appear in the issuer block; if only a person appears, use that person’s name.
#         - Extract only the name line (omit address/contact).
#         - Do NOT use template/theme/descriptor titles as the company, such as:
#           - “Beige Gray Simple Minimalist Consultation Invoice”
#           - “Green IT Company Professional Service Invoice”
#           - “Pink Modern Service Invoice”
#           - “Freelance Invoice Template”
#           These are not company names.
#
#         2) billed_to (the customer/recipient being invoiced)
#         - Look for: “Bill To”, “Billed To”, “Invoice To”, “Customer”, “Client”, “To:”, “ISSUED TO:”.
#         - Prefer the customer company name over a contact person if both are present; if only a person is present, use the person’s name.
#         - Extract only the name line (omit address/contact).
#         - Important: “PAY TO” (or “Pay To”) denotes the issuer (company), NOT the customer. Do not use “PAY TO” for billed_to.
#
#         3) invoice_number
#         - Look for labels: “Invoice Number”, “Invoice No”, “Invoice #”, “Invoice NO.”, “Invoice ID”, “INVOICE NO.”, “INVOICE NO:”, “INVOICE ID:”.
#         - Also accept a standalone “#12345” near the invoice header when clearly serving as the invoice number.
#         - Preserve the exact formatting, including prefixes, leading zeros, separators, and “#” if present.
#
#         4) invoice_date (the invoice issue date)
#         - Prefer labels: “Invoice Date”, “Date of Issue”, “Issue Date”, “DATE:”, “Date”.
#         - Do NOT use “Service Date”, “Due Date”, or “Payment Date”.
#         - If only an unlabeled date appears near the invoice header/number and no other date types are present, treat it as the invoice date.
#         - Preserve the original formatting (e.g., “08/01/2023”, “11.02.2030”, “5 December 2030”).
#
#         5) total_amount (grand total due)
#         - Prefer labels in the summary/totals section: “TOTAL”, “TOTAL AMOUNT DUE”, “TOTAL AMOUNT”, “Amount Due”, “Balance Due”, “Grand Total”, “Total Amount”.
#         - Choose the final payable total from the summary block (often at or near the end), not a line-item total.
#         - Do NOT use “Sub-Total”, “Subtotal”, “Tax”, “Discount”, or intermediate sums.
#         - If multiple total-like amounts exist:
#           - Prefer “Amount Due”, “Total Amount”, “Grand Total”, “Balance Due” over a generic “Total” if both are present.
#           - Ignore percentages or rates (e.g., lines with “10%”).
#           - Pick the amount nearest to the clearest total label within the summary block.
#
#         6) bank_name
#         - Look for “Bank Name:”, “Bank:”, or an unlabeled bank name line within a “Bank Details/Bank Information” section.
#         - Do NOT return “Bank Code” or routing numbers as the bank_name unless the actual bank name is explicitly provided.
#
#         7) account_name
#         - Look for “Account Name”, “Account Holder”, “Beneficiary Name” within payment/bank details.
#         - Use only explicitly labeled values; do not infer from unrelated context or roles.
#
#         8) account_number
#         - Look for “Account Number”, “Account No”, “Acct No”, “A/C No”, “AC No.”, “A/C #”.
#         - Preserve formatting (retain spaces/dashes), e.g., “123-456-7890”, “0123 4567 8901”.
#         - If only an IBAN is provided and no separate account number is present, use the IBAN as account_number (preserve its formatting).
#         - Do NOT use routing numbers, bank codes, or SWIFT/BIC as account_number.
#
#         Disambiguation and edge cases
#         - Template/theme headings are NOT company names. Ignore stylistic/descriptor titles even if they contain industry terms (e.g., “Green IT Company Professional Service Invoice”).
#         - “Freelancer: <name>”, “Service Provider”, “PAY TO”, and “From” typically indicate the issuer (company).
#         - “ISSUED TO”, “Bill To”, “Client/Customer” indicate the recipient (billed_to).
#         - Multi-line blocks: when a block contains name + address/contact, extract only the name line for company or billed_to.
#         - If a clearly labeled bank detail coincides with a party name (e.g., account_name equals the customer), still extract the labeled bank fields as shown; do not reinterpret roles.
#         - If a field cannot be confidently located, set it to "".
#
#         Validation before output
#         - Ensure all 8 keys are present with string values.
#         - Ensure invoice_date is used as the date key (not “date” or any other variant).
#         - Preserve exact source formatting for all extracted values.
#         - Return only the JSON object, with no extra commentary.
#
#
# User message:
#
# [[ ## text ## ]]
# Yellow and Black Professional Company Invoice
#
# No Items Qty Price Total
# 1 Cement 50 $20.00 $1000.00
# 2 Pvc Pipe 10 $10.00 $100.00
# 3 Brick 10 $10.00 $100.00
# 4 Wood Board 10 $10.00 $100.00
# Taylor Alonso
# Ginyard International Bank
# Bank Code (123-456-7890)
# Total $1200.00
# INVOICE
# Ingoude
# Company
# Jonathan Patterson
# +123-456-7890
# Invoice to
# #123456789
# 3rd January 2024
# Payment Terms
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# THANK YOU
#
# Respond with the corresponding output fields, starting with the field `[[ ## rationale ## ]]`, then `[[ ## extracted ## ]]` (must be formatted as a valid Python dict), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## rationale ## ]]
# Detected fields:
# - company: "Ingoude Company" — appears directly under the "INVOICE" header ("INVOICE\nIngoude\nCompany"), chosen as the issuing company (ignoring the template title at the top).
# - billed_to: "Taylor Alonso" — name present after the item list, taken as the customer/recipient.
# - invoice_number: "#123456789" — line immediately below "Invoice to".
# - invoice_date: "3rd January 2024" — date shown next to the invoice/recipient block.
# - total_amount: "$1200.00" — "Total $1200.00" in the totals area; amount preserved with currency symbol.
# - bank_name: "Ginyard International Bank" — explicit bank name shown near the top of the payment block.
# - account_name: "" — no explicit "Account Name" / "Account Holder" / "Beneficiary" label present.
# - account_number: "" — no explicit "Account Number" / "A/C No" or IBAN present; only "Bank Code (123-456-7890)" which is not an account number.
#
# [[ ## extracted ## ]]
# {
#   "company": "Ingoude Company",
#   "billed_to": "Taylor Alonso",
#   "invoice_number": "#123456789",
#   "invoice_date": "3rd January 2024",
#   "total_amount": "$1200.00",
#   "bank_name": "Ginyard International Bank",
#   "account_name": "",
#   "account_number": ""
# }
# [[ ## completed ## ]]
